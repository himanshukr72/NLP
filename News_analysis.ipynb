# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshukr72/NLP/blob/main/News_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# !pip install numpy pandas matplotlib scikit-learn gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 58.9 MB/s eta 0:00:00
# ...

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9686 sha256=279d1fb0ef35a867cd4363cbcc1a900488b52c131d58abe1782719ac0dcb970d
#   Stored in directory: /root/.cache/pip/wheels/8a/b8/04/0c88fb22489b0c049bee4e977c5689c7fe597d6c4b0e7d0b6a
# Successfully built wget
# ...

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2026-09-19 13:01:16--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 16.15.236.144, 52.216.8.245, 16.15.255.73, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|16.15.236.144|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-09-19 13:01:17 ERROR 404: Not Found.

# %%
# !ls -lh
# Out:
# total 4.0K
# drwxr-xr-x 1 root root 4.0K Sep  4 13:32 sample_data

# %%
# !wget -O GoogleNews-vectors-negative300.bin.gz \
"https://huggingface.co/LoganKilpatrick/GoogleNews-vectors-negative300/resolve/main/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2026-09-19 13:01:17--  https://huggingface.co/LoganKilpatrick/GoogleNews-vectors-negative300/resolve/main/GoogleNews-vectors-negative300.bin.gz
# Resolving huggingface.co (huggingface.co)... 13.35.202.121, 13.35.202.34, 13.35.202.97, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.121|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/63b498753e02c8e7cb761fd6/cfc9eb89061e73f7973c80e2a2a76bf487edcb4f55dd4bab1b3d4bdcfef40332?response-content-type=application%2Fgzip&X-Xet-Cas-Uid=public&user_id=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27GoogleNews-vectors-negative300.bin.gz%3B+filename%3D%22GoogleNews-vectors-negative300.bin.gz%22%3B&Expires=1789826478&Policy=...&Signature=MEUCIHJOBat4su6YqF11dMoLyZ30iXK80DLwoz1-bQ4CZJMbAiEAoAHweB3BeIPQBXGYsSLtShHPIVRWKoErV4MpP%7EGCE7A_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F&Hash-Algorithm=SHA256 [following]
# ...

# %%
# !ls -lh GoogleNews-vectors-negative300.bin.gz
# Out:
# -rw-r--r-- 1 root root 1.6G Sep 19 13:01 GoogleNews-vectors-negative300.bin.gz

# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load_word2vec_format(
    "GoogleNews-vectors-negative300.bin.gz",
    binary=True
)

# %%
model["cricket"]
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
model.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367618441581726),
#  ('linkedin', 0.6356592774391174)]

# %%
model.similarity('man','woman')
# Out:
# np.float32(0.76640123)

# %%
model.similarity('man','PHP')
# Out:
# np.float32(-0.032995153)

# %%
model.doesnt_match(['PHP','java','monkey'])
# Out:
# 'monkey'

# %%
vec = model['INR'] - model ['India'] + model['England']
model.most_similar([vec])
# Out:
# [('INR', 0.6442341208457947),
#  ('GBP', 0.5040826797485352),
#  ('£_##.###m', 0.4540838301181793),
#  ('England', 0.44649264216423035),
#  ('£', 0.43340998888015747),
#  ('Â_£', 0.4307197630405426),
#  ('stg###', 0.4299262464046478),
#  ('£_#.##m', 0.42561301589012146),
#  ('Pounds_Sterling', 0.42512619495391846),
#  ('GBP##', 0.42464491724967957)]
